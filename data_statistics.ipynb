# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import itertools
import os
import warnings

import numpy as np
import pandas as pd

from sklearn.metrics import cohen_kappa_score
from statsmodels.stats.inter_rater import fleiss_kappa, aggregate_raters

from data import _preprocess, COLUMNS

# %% [markdown]
# ### LOAD TEST SET

# %%
TEST_DATA_FILE_NAME = '../data/temporal/preprocessed_test.pkl'
test_df = _preprocess(pd.read_pickle(TEST_DATA_FILE_NAME))

# TODO fix this upstream somewhere
test_df['answer_pp_toxicity'] = test_df['answer_toxicity']

# extract language from filename
test_df['lang'] = test_df['filename'].str.extract(r'batch_(..)_\d+\.csv')
test_df['lang'].unique()
# Out:
# array(['nl', 'en', 'es', 'tr', 'ar', 'de'], dtype=object)

# %%
TRAIN_DATA_FILE_NAME = '../data/temporal/preprocessed_train.pkl'
train_df = _preprocess(pd.read_pickle(TRAIN_DATA_FILE_NAME))
test_df['lang'] = test_df['filename'].str.extract(r'batch_(.*)_ChatGPT_hate_speech_or_not_\d+.csv')
# Out:
# 0          batch_English_ChatGPT_hate_speech_or_not_14.csv
# 1           batch_Turkish_ChatGPT_hate_speech_or_not_3.csv
# 2          batch_English_ChatGPT_hate_speech_or_not_56.csv
# 3         batch_English_ChatGPT_hate_speech_or_not_188.csv
# 4         batch_English_ChatGPT_hate_speech_or_not_186.csv
#                                 ...
# 127467    batch_English_ChatGPT_hate_speech_or_not_173.csv
# 127468     batch_Spanish_ChatGPT_hate_speech_or_not_12.csv
# 127469      batch_Turkish_ChatGPT_hate_speech_or_not_3.csv
# 127470     batch_English_ChatGPT_hate_speech_or_not_87.csv
# 127471     batch_English_ChatGPT_hate_speech_or_not_10.csv
# Name: filename, Length: 127472, dtype: object

# %% [markdown]
# ### Select data

# %%
df = train_df

# %% [markdown]
# ### Calculate statistics

# %%
st_counts = df.groupby('lang')[['st_id']].nunique().rename(columns={'st_id': 'Nr. sub-threads'})
st_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 st_counts = df.groupby('lang')[['st_id']].nunique().rename(columns={'st_id': 'Nr. sub-threads'})
#       2 st_counts
#
# File ~/Projects/toxic-reasoning/env-models/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~/Projects/toxic-reasoning/env-models/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/Projects/toxic-reasoning/env-models/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'lang'

# %%
by_st = df.groupby(['lang', 'st_id'])[['comment_id']].nunique().reset_index()  # contains nr of comments for each sub thread
by_lang = by_st.groupby('lang')[['comment_id']]                                     # grouped by language
avg_length = by_lang.mean().rename(columns={'comment_id': 'Avg. Length'})
min_length = by_lang.min().rename(columns={'comment_id': 'Min. length'})
max_length = by_lang.max().rename(columns={'comment_id': 'Max. length'})
st_length_df = pd.concat([avg_length, min_length, max_length], axis=1)
st_length_df
# Out:
#       Avg. Length  Min. length  Max. length
# lang
# ar       5.500000            4           10
# de       5.216495            4           10
# en       5.098039            4           10
# es       5.439560            4           10
# nl       5.303797            4            9
# tr       5.232558            4           10

# %%
# calculate counts for toxicity ('Yes/Maybe' vs. 'No'), based on majority vote
def majority_vote(series):
    modes = series.mode()
    if len(modes) == 1:
        return modes.iloc[0]
    elif len(modes) == 0:
        return None
    return "{" + ",".join(str(v) for v in modes.tolist()) + "}"

COLS = ['lang', 'comment_id', 'answer_pp_toxicity', 'answer_pp_counternarrative', 'answer_pp_justInappropriate', 'answer_pp_hasImplication', 'answer_pp_hasOther']
maj_df = df[COLS].groupby(['lang', 'comment_id']).agg(majority_vote).reset_index()

toxicity = maj_df.groupby(['lang', 'answer_pp_toxicity'])[['comment_id']].nunique().reset_index()
toxicity = toxicity.pivot(index='lang', columns='answer_pp_toxicity', values='comment_id')
toxicity['Total comments'] = toxicity['No'] + toxicity['Yes/Maybe']
toxicity = toxicity.rename(columns={'No': 'Nr. of non-toxic', 'Yes/Maybe': 'Nr. of possibly toxic comments'})
toxicity
# Out:
# answer_pp_toxicity  Nr. of non-toxic  Nr. of possibly toxic comments  \
# lang
# ar                             293.0                           213.0
# de                             246.0                           260.0
# en                             319.0                           201.0
# es                             232.0                           263.0
# nl                             265.0                           136.0
# tr                             233.0                           217.0
#
# answer_pp_toxicity  {No,Yes/Maybe}  Total comments
# lang
# ar                             NaN           506.0
# de                             NaN           506.0
# en                             NaN           520.0
# es                             NaN           495.0
# nl                            18.0           401.0
# tr                             NaN           450.0

# %%
impl_topic = df.groupby(['lang', 'answer_pp_implTopic'])[['comment_id']].nunique().reset_index()
impl_topic = impl_topic.pivot(index='lang', columns='answer_pp_implTopic', values='comment_id')
impl_topic
# Out:
# answer_pp_implTopic   (a)  (a.1)    (b)  (b.1)    (c)  (d)   (e)
# lang
# ar                   14.0   11.0   54.0    8.0  122.0  7.0  11.0
# de                   20.0   11.0   64.0    4.0   96.0  2.0   9.0
# en                   40.0   24.0   51.0    3.0  169.0  7.0   3.0
# es                   45.0   29.0  118.0   26.0  141.0  3.0  20.0
# nl                   16.0   23.0   24.0    3.0  149.0  3.0   3.0
# tr                    9.0    NaN   40.0   13.0   78.0  5.0   3.0

# %%
impl_polarity = df.groupby(['lang', 'answer_pp_implPolarity'])[['comment_id']].nunique().reset_index()
impl_polarity = impl_polarity.pivot(index='lang', columns='answer_pp_implPolarity', values='comment_id')
impl_polarity
# Out:
# answer_pp_implPolarity  Negative  Neutral  Positive
# lang
# ar                         157.0     13.0      10.0
# de                         160.0      6.0       8.0
# en                         219.0     83.0      23.0
# es                         275.0     21.0       8.0
# nl                         169.0     10.0      12.0
# tr                         115.0      6.0       NaN

# %%
MAPPING = {
    '(a)': 'Circumstances', '(a.1)': 'Harm',
    '(b)': 'Qualities', '(b.1)': 'Dehumanization',
    '(c)': 'Choices',
    '(d)': '-NonSpecific',
    '(e)': '-UnclearOrNone',
}
ILLEGAL = ['PositiveHarm', 'NeutralHarm', 'PositiveDehumanization', 'NeutralDehumanization']

def convert(row):
    topic = row['answer_pp_implTopic']
    polarity = row['answer_pp_implPolarity']
    if pd.isna(topic):
        return pd.NA
    name = str(MAPPING[topic]) if topic.endswith('.1)') else str(polarity) + str(MAPPING[topic])
    if name in ILLEGAL:
        return 'ILLEGAL'
    return name

implType = pd.concat([df[['lang', 'comment_id']], df.apply(convert, axis=1).rename('Implication Type')], axis=1)
implType = implType.groupby(['lang', 'Implication Type'])['comment_id'].nunique().reset_index()
implType = implType.pivot(index='lang', columns='Implication Type', values='comment_id')
implType
# Out:
# Implication Type  Dehumanization  Harm  Negative-NonSpecific  \
# lang
# ar                           8.0  11.0                   2.0
# de                           4.0  11.0                   2.0
# en                           3.0  24.0                   2.0
# es                          26.0  29.0                   2.0
# nl                           3.0  23.0                   NaN
# tr                          13.0   NaN                   5.0
#
# Implication Type  Negative-UnclearOrNone  NegativeChoices  \
# lang
# ar                                   8.0            116.0
# de                                   5.0             90.0
# en                                   NaN            137.0
# es                                  12.0            135.0
# nl                                   2.0            139.0
# tr                                   3.0             76.0
#
# Implication Type  NegativeCircumstances  NegativeQualities  \
# lang
# ar                                 12.0               51.0
# de                                 17.0               62.0
# en                                 26.0               30.0
# es                                 41.0              110.0
# nl                                 11.0               24.0
# tr                                  9.0               37.0
#
# Implication Type  Neutral-NonSpecific  Neutral-UnclearOrNone  NeutralChoices  \
# lang
# ar                                1.0                    3.0             6.0
# de                                NaN                    NaN             2.0
# en                                5.0                    2.0            37.0
# es                                NaN                    8.0             5.0
# nl                                3.0                    1.0             5.0
# tr                                NaN                    NaN             2.0
#
# Implication Type  ...  NeutralQualities  None-UnclearOrNone  NoneChoices  \
# lang              ...
# ar                ...               1.0                 NaN          NaN
# de                ...               2.0                 3.0          NaN
# en                ...              20.0                 1.0          3.0
# es                ...               5.0                 NaN          NaN
# nl                ...               NaN                 NaN          2.0
# tr                ...               4.0                 NaN          NaN
#
# Implication Type  NoneCircumstances  NoneQualities  Positive-NonSpecific  \
# lang
# ar                              NaN            NaN                   4.0
# de                              NaN            NaN                   NaN
# en                              NaN            NaN                   NaN
# es                              1.0            2.0                   1.0
# nl                              NaN            NaN                   NaN
# tr                              NaN            NaN                   NaN
#
# Implication Type  Positive-UnclearOrNone  PositiveChoices  \
# lang
# ar                                   NaN              4.0
# de                                   1.0              5.0
# en                                   NaN              9.0
# es                                   NaN              5.0
# nl                                   NaN              7.0
# tr                                   NaN              NaN
#
# Implication Type  PositiveCircumstances  PositiveQualities
# lang
# ar                                  1.0                2.0
# de                                  2.0                NaN
# en                                  5.0                4.0
# es                                  1.0                2.0
# nl                                  5.0                NaN
# tr                                  NaN                NaN
#
# [6 rows x 21 columns]

# %%
print([type(x) for x in [st_counts, st_length_df, toxicity, impl_topic, impl_polarity, implType]])

all_stats = pd.concat([st_counts, st_length_df, toxicity, impl_topic, impl_polarity, implType], axis=1)
all_stats = all_stats.transpose()
all_stats.to_csv('data_stats.csv')
all_stats
# Out:
# [<class 'pandas.core.frame.DataFrame'>, <class 'pandas.core.frame.DataFrame'>, <class 'pandas.core.frame.DataFrame'>, <class 'pandas.core.frame.DataFrame'>, <class 'pandas.core.frame.DataFrame'>, <class 'pandas.core.frame.DataFrame'>]
# lang                               ar          de          en         es  \
# Nr. sub-threads                  92.0   97.000000  102.000000   91.00000
# Avg. Length                       5.5    5.216495    5.098039    5.43956
# Min. length                       4.0    4.000000    4.000000    4.00000
# Max. length                      10.0   10.000000   10.000000   10.00000
# Nr. of non-toxic                293.0  246.000000  319.000000  232.00000
# Nr. of possibly toxic comments  213.0  260.000000  201.000000  263.00000
# {No,Yes/Maybe}                    NaN         NaN         NaN        NaN
# Total comments                  506.0  506.000000  520.000000  495.00000
# (a)                              14.0   20.000000   40.000000   45.00000
# (a.1)                            11.0   11.000000   24.000000   29.00000
# (b)                              54.0   64.000000   51.000000  118.00000
# (b.1)                             8.0    4.000000    3.000000   26.00000
# (c)                             122.0   96.000000  169.000000  141.00000
# (d)                               7.0    2.000000    7.000000    3.00000
# (e)                              11.0    9.000000    3.000000   20.00000
# Negative                        157.0  160.000000  219.000000  275.00000
# Neutral                          13.0    6.000000   83.000000   21.00000
# Positive                         10.0    8.000000   23.000000    8.00000
# Dehumanization                    8.0    4.000000    3.000000   26.00000
# Harm                             11.0   11.000000   24.000000   29.00000
# Negative-NonSpecific              2.0    2.000000    2.000000    2.00000
# Negative-UnclearOrNone            8.0    5.000000         NaN   12.00000
# NegativeChoices                 116.0   90.000000  137.000000  135.00000
# NegativeCircumstances            12.0   17.000000   26.000000   41.00000
# NegativeQualities                51.0   62.000000   30.000000  110.00000
# Neutral-NonSpecific               1.0         NaN    5.000000        NaN
# Neutral-UnclearOrNone             3.0         NaN    2.000000    8.00000
# NeutralChoices                    6.0    2.000000   37.000000    5.00000
# NeutralCircumstances              1.0    2.000000    9.000000    3.00000
# NeutralQualities                  1.0    2.000000   20.000000    5.00000
# None-UnclearOrNone                NaN    3.000000    1.000000        NaN
# NoneChoices                       NaN         NaN    3.000000        NaN
# NoneCircumstances                 NaN         NaN         NaN    1.00000
# NoneQualities                     NaN         NaN         NaN    2.00000
# Positive-NonSpecific              4.0         NaN         NaN    1.00000
# Positive-UnclearOrNone            NaN    1.000000         NaN        NaN
# PositiveChoices                   4.0    5.000000    9.000000    5.00000
# PositiveCircumstances             1.0    2.000000    5.000000    1.00000
# PositiveQualities                 2.0         NaN    4.000000    2.00000
#
# lang                                    nl          tr
# Nr. sub-threads                  79.000000   86.000000
# Avg. Length                       5.303797    5.232558
# Min. length                       4.000000    4.000000
# Max. length                       9.000000   10.000000
# Nr. of non-toxic                265.000000  233.000000
# Nr. of possibly toxic comments  136.000000  217.000000
# {No,Yes/Maybe}                   18.000000         NaN
# Total comments                  401.000000  450.000000
# (a)                              16.000000    9.000000
# (a.1)                            23.000000         NaN
# (b)                              24.000000   40.000000
# (b.1)                             3.000000   13.000000
# (c)                             149.000000   78.000000
# (d)                               3.000000    5.000000
# (e)                               3.000000    3.000000
# Negative                        169.000000  115.000000
# Neutral                          10.000000    6.000000
# Positive                         12.000000         NaN
# Dehumanization                    3.000000   13.000000
# Harm                             23.000000         NaN
# Negative-NonSpecific                   NaN    5.000000
# Negative-UnclearOrNone            2.000000    3.000000
# NegativeChoices                 139.000000   76.000000
# NegativeCircumstances            11.000000    9.000000
# NegativeQualities                24.000000   37.000000
# Neutral-NonSpecific               3.000000         NaN
# Neutral-UnclearOrNone             1.000000         NaN
# NeutralChoices                    5.000000    2.000000
# NeutralCircumstances                   NaN         NaN
# NeutralQualities                       NaN    4.000000
# None-UnclearOrNone                     NaN         NaN
# NoneChoices                       2.000000         NaN
# NoneCircumstances                      NaN         NaN
# NoneQualities                          NaN         NaN
# Positive-NonSpecific                   NaN         NaN
# Positive-UnclearOrNone                 NaN         NaN
# PositiveChoices                   7.000000         NaN
# PositiveCircumstances             5.000000         NaN
# PositiveQualities                      NaN         NaN
